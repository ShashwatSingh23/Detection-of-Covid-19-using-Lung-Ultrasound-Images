# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# !git clone https://github.com/jannisborn/covid19_ultrasound.git
# Out:
# Cloning into 'covid19_ultrasound'...
# remote: Enumerating objects: 4503, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 4503 (delta 21), reused 20 (delta 6), pack-reused 4453
# Receiving objects: 100% (4503/4503), 165.47 MiB | 37.53 MiB/s, done.
# Resolving deltas: 100% (353/353), done.
# Updating files: 100% (3872/3872), done.

# %%
meta_data = pd.read_csv('./covid19_ultrasound/data/dataset_metadata.csv')

# %%
meta_data[meta_data['InThisRepo'] == 'Yes']
# Out:
#     Date added          Current location                  Filename  \
# 21    20.04.20  data/pocus_videos/Convex            Cov-Atlas+(44)
# 22    20.04.20  data/pocus_videos/Convex            Cov-Atlas+(45)
# 23    20.04.20  data/pocus_videos/Convex           Cov-Atlas-Day+2
# 24    20.04.20  data/pocus_videos/Convex           Cov-Atlas-Day+4
# 25    20.04.20  data/pocus_videos/Convex      Pneu-Atlas-pneumonia
# ..         ...                       ...                       ...
# 364   19.01.21       pocus_images/convex  Cov_Oliviera_2020_Fig15A
# 365   19.01.21       pocus_images/linear   Cov_Oliviera_2020_Fig16
# 371   19.01.21       pocus_videos/convex           Cov_emdocs_vid1
# 372   19.01.21       pocus_videos/linear           Cov_emdocs_vid2
# 373   19.01.21       pocus_videos/convex           Cov_emdocs_vid3
#
#                                       URL (Video Name)                Label  \
# 21   http://www.thepocusatlas.com/covid19-1/m2ra6cg...             COVID-19
# 22   http://www.thepocusatlas.com/covid19-1/3ytz1el...             COVID-19
# 23         http://www.thepocusatlas.com/covid19 (Day2)             COVID-19
# 24         http://www.thepocusatlas.com/covid19 (Day4)             COVID-19
# 25   http://www.thepocusatlas.com/ (Classic Finding...  Bacterial pneumonia
# ..                                                 ...                  ...
# 364  https://www.scielo.br/img/revistas/rb/v53n4//0...             COVID-19
# 365  https://www.scielo.br/img/revistas/rb/v53n4//0...             COVID-19
# 371  http://www.emdocs.net/wp-content/uploads/2020/...             COVID-19
# 372  http://www.emdocs.net/wp-content/uploads/2020/...             COVID-19
# 373  http://www.emdocs.net/wp-content/uploads/2020/...             COVID-19
#
#      Lung Severity Score       License  \
# 21                   2.0  CC BY-NC 4.0
# 22                   3.0  CC BY-NC 4.0
# 23                   1.0  CC BY-NC 4.0
# 24                   3.0  CC BY-NC 4.0
# 25                   NaN  CC BY-NC 4.0
# ..                   ...           ...
# 364                  NaN     CC BY 4.0
# 365                  NaN     CC BY 4.0
# 371                  NaN     CC BY 4.0
# 372                  3.0     CC BY 4.0
# 373                  NaN     CC BY 4.0
#
#                                         LinkToLicense ChangesMade InThisRepo  \
# 21   https://creativecommons.org/licenses/by-nc/4.0/#    Cropping        Yes
# 22   https://creativecommons.org/licenses/by-nc/4.0/#    Cropping        Yes
# 23   https://creativecommons.org/licenses/by-nc/4.0/#    Cropping        Yes
# 24   https://creativecommons.org/licenses/by-nc/4.0/#    Cropping        Yes
# 25   https://creativecommons.org/licenses/by-nc/4.0/#    Cropping        Yes
# ..                                                ...         ...        ...
# 364      https://creativecommons.org/licenses/by/4.0/    Cropping        Yes
# 365      https://creativecommons.org/licenses/by/4.0/    Cropping        Yes
# 371      https://creativecommons.org/licenses/by/4.0/    Cropping        Yes
# 372      https://creativecommons.org/licenses/by/4.0/    Cropping        Yes
# 373      https://creativecommons.org/licenses/by/4.0/    Cropping        Yes
#
#      ... Healthy Fever Cough  Respiratory problems Headache  \
# 21   ...     0.0     1     0                     1        0
# 22   ...     0.0     1     0                     1        0
# 23   ...     0.0   n/A   n/A                   n/A      n/A
# 24   ...     0.0   n/A   n/A                   n/A      n/A
# 25   ...     0.0   n/A   n/A                   n/A      n/A
# ..   ...     ...   ...   ...                   ...      ...
# 364  ...     NaN   n/A   n/A                   n/A      n/A
# 365  ...     NaN   n/A   n/A                   n/A      n/A
# 371  ...     NaN   n/A   n/A                   n/A      n/A
# 372  ...     NaN   n/A   n/A                   n/A      n/A
# 373  ...     NaN   n/A   n/A                   n/A      n/A
#
#     Loss of smell/taste Fatigue Sore throat Asymptomatic  Other
# 21                    0       0           0            0    NaN
# 22                    0       0           0            0    NaN
# 23                  n/A     n/A         n/A          n/A    NaN
# 24                  n/A     n/A         n/A          n/A    NaN
# 25                  n/A     n/A         n/A          n/A    NaN
# ..                  ...     ...         ...          ...    ...
# 364                 n/A     n/A         n/A          n/A    NaN
# 365                 n/A     n/A         n/A          n/A    NaN
# 371                 n/A     n/A         n/A          n/A    NaN
# 372                 n/A     n/A         n/A          n/A    NaN
# 373                 n/A     n/A         n/A          n/A    NaN
#
# [171 rows x 45 columns]

# %%
base_dir = "./covid19_ultrasound/data/"
out_table = pd.DataFrame(index=['cov', 'pne', 'reg', 'vir'])
for modality in ["convex", "linear"]:
    for datatype in ["videos", "images"]:
        path = os.path.join(base_dir, "pocus_" + datatype, modality)
        file_list = filter(
            lambda x: (
                x[0] != "." and os.path.isfile(os.path.join(path, x)) and
                not "_Butterfly" in x
            ), os.listdir(path)
        )
        label_list = [f[:3].lower() for f in file_list]
        counts = [
            label_list.count(lab) for lab in ['cov', 'pne', 'reg', 'vir']
        ]
        out_table[modality + "_" + datatype] = counts
print("Data without Butterfly:")
print(out_table)
# Out:
# Data without Butterfly:
#      convex_videos  convex_images  linear_videos  linear_images
# cov             30              5              3              3
# pne             36             14              1              0
# reg             56             10              3              0
# vir              2              0              3              0

# %%
meta_data
# Out:
#     Date added     Current location                             Filename  \
# 0     20.04.20            butterfly           Cov-Butterfly-COVID Lung 2
# 1     20.04.20            butterfly            Cov-Butterfly-Skip Lesion
# 2     20.04.20            butterfly      Cov-Butterfly-Confluent B lines
# 3     20.04.20            butterfly    Reg-Butterfly-Normal Lung A lines
# 4     20.04.20            butterfly  Reg-Butterfly-Normal Lung_Example 2
# ..         ...                  ...                                  ...
# 369   19.01.21  pocus_videos/convex                   Cov_wfumb_case_dez
# 370   19.01.21  pocus_videos/convex             Cov_Arnthfield_2020_Vid3
# 371   19.01.21  pocus_videos/convex                      Cov_emdocs_vid1
# 372   19.01.21  pocus_videos/linear                      Cov_emdocs_vid2
# 373   19.01.21  pocus_videos/convex                      Cov_emdocs_vid3
#
#                                       URL (Video Name)     Label  \
# 0    https://www.butterflynetwork.com/covid-19#lung...  COVID-19
# 1    https://www.butterflynetwork.com/covid19/covid...  COVID-19
# 2    https://www.butterflynetwork.com/covid19/covid...  COVID-19
# 3    https://www.butterflynetwork.com/covid19/covid...   regular
# 4    https://www.butterflynetwork.com/covid19/covid...   regular
# ..                                                 ...       ...
# 369  https://www.youtube.com/watch?v=CpXPimphNSM&fe...  COVID-19
# 370  https://www.medrxiv.org/content/10.1101/2020.1...  COVID-19
# 371  http://www.emdocs.net/wp-content/uploads/2020/...  COVID-19
# 372  http://www.emdocs.net/wp-content/uploads/2020/...  COVID-19
# 373  http://www.emdocs.net/wp-content/uploads/2020/...  COVID-19
#
#      Lung Severity Score      License  \
# 0                    NaN         None
# 1                    NaN         None
# 2                    2.0         None
# 3                    NaN         None
# 4                    0.0         None
# ..                   ...          ...
# 369                  NaN         None
# 370                  NaN  CC-BY-NC-ND
# 371                  NaN    CC BY 4.0
# 372                  3.0    CC BY 4.0
# 373                  NaN    CC BY 4.0
#
#                                          LinkToLicense  \
# 0                                                 N.A.
# 1                                                 N.A.
# 2                                                 N.A.
# 3                                                 N.A.
# 4                                                 N.A.
# ..                                                 ...
# 369                                               N.A.
# 370  https://creativecommons.org/licenses/by-nc-nd/...
# 371       https://creativecommons.org/licenses/by/4.0/
# 372       https://creativecommons.org/licenses/by/4.0/
# 373       https://creativecommons.org/licenses/by/4.0/
#
#                                         ChangesMade InThisRepo  ... Healthy  \
# 0    Cropping, Artifact removal, frame subselection         No  ...     0.0
# 1    Cropping, Artifact removal, frame subselection         No  ...     0.0
# 2    Cropping, Artifact removal, frame subselection         No  ...     0.0
# 3    Cropping, Artifact removal, frame subselection         No  ...     1.0
# 4    Cropping, Artifact removal, frame subselection         No  ...     1.0
# ..                                              ...        ...  ...     ...
# 369                                        Cropping         No  ...     NaN
# 370                                        Cropping         No  ...     NaN
# 371                                        Cropping        Yes  ...     NaN
# 372                                        Cropping        Yes  ...     NaN
# 373                                        Cropping        Yes  ...     NaN
#
#     Fever Cough  Respiratory problems Headache Loss of smell/taste Fatigue  \
# 0     n/A   n/A                   n/A      n/A                 n/A     n/A
# 1     n/A   n/A                   n/A      n/A                 n/A     n/A
# 2     n/A   n/A                   n/A      n/A                 n/A     n/A
# 3     n/A   n/A                   n/A      n/A                 n/A     n/A
# 4     n/A   n/A                   n/A      n/A                 n/A     n/A
# ..    ...   ...                   ...      ...                 ...     ...
# 369     0     0                     0        0                   0       0
# 370   n/A   n/A                   n/A      n/A                 n/A     n/A
# 371   n/A   n/A                   n/A      n/A                 n/A     n/A
# 372   n/A   n/A                   n/A      n/A                 n/A     n/A
# 373   n/A   n/A                   n/A      n/A                 n/A     n/A
#
#     Sore throat Asymptomatic  Other
# 0           n/A          n/A    NaN
# 1           n/A          n/A    NaN
# 2           n/A          n/A    NaN
# 3           n/A          n/A    NaN
# 4           n/A          n/A    NaN
# ..          ...          ...    ...
# 369           0            1    NaN
# 370         n/A          n/A    NaN
# 371         n/A          n/A    NaN
# 372         n/A          n/A    NaN
# 373         n/A          n/A    NaN
#
# [374 rows x 45 columns]

# %%
def label_enc(idx):
    if idx == 'COVID-19':
        return 2
    elif idx == 'Bacterial pneumonia':
        return 1
    elif idx == 'Viral pneumonia':
        return 1
    else:
        return 0
meta_data['Label'] = meta_data['Label'].apply(label_enc)

# %%
meta_data['InThisRepo']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 369     No
# 370     No
# 371    Yes
# 372    Yes
# 373    Yes
# Name: InThisRepo, Length: 374, dtype: object

# %%
possible_endings = [
       ".mp4", ".mpeg", ".avi", ".gif",
    ".mov"
]
base = './covid19_ultrasound/data/'
table = meta_data
#table = table[table['InThisRepo'] == 'Yes']
real_paths = []
labels = []
in_this_repos = []
for i in range(len(table)):
    fn = table.iloc[i]["Filename"]
    location = table.iloc[i]["Current location"].lower()
    if pd.isnull(location) or 'data_with_artifacts' in location:
        continue
    if location.startswith("data/"):
        location = location[5:]

    path1 = os.path.join(base, location, fn)
    path2 = ".".join(path1.split(".")[:-1]) + ".mp4"
    for ending in possible_endings:
        if os.path.exists(path1 + ending):
            table = table.copy()
            real_path = path1+ending
            label = table['Label'].iloc[i]
            in_this_repo = table['InThisRepo'].iloc[i]
            
            real_paths.append(real_path)
            labels.append(label)
            in_this_repos.append(in_this_repo)

preprocessed_metadata = pd.DataFrame({'path':real_paths,'label':labels,'in_this_repo':in_this_repos})

# %%
vid_path = preprocessed_metadata['path'].iloc[0]

# %%
vidcap = cv2.VideoCapture(vid_path)
success,image = vidcap.read()

# %%
preprocessed_metadata
# Out:
#                                                   path  label in_this_repo
# 0    ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 1    ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 2    ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 3    ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 4    ./covid19_ultrasound/data/pocus_videos/convex/...      1          Yes
# ..                                                 ...    ...          ...
# 127  ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 128  ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 129  ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
# 130  ./covid19_ultrasound/data/pocus_videos/linear/...      2          Yes
# 131  ./covid19_ultrasound/data/pocus_videos/convex/...      2          Yes
#
# [132 rows x 3 columns]

# %%
# !mkdir data

# %%
paths = []
labels = []
video_ids = []
for i in tqdm(range(len(preprocessed_metadata))):
    vidcap = cv2.VideoCapture(preprocessed_metadata['path'].iloc[i])
    success,image = vidcap.read()
    count = 0
    while success:
        path = f"./data/Video_{i}_frame_%d.jpg" % count
        video_id = f'Video_{i}'
        cv2.imwrite(path, image)     # save frame as JPEG file      
        success,image = vidcap.read()
        print('Read a new frame: ', success)
        count += 1
        paths.append(path)
        video_ids.append(video_id)
        labels.append(preprocessed_metadata['label'].iloc[i])
        
metadata_final = pd.DataFrame({'path':paths,'label':labels,'video_id':video_ids})
# Out:
#   0%|          | 0/132 [00:00<?, ?it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#   2%|▏         | 3/132 [00:00<00:07, 17.27it/s]
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#   4%|▍         | 5/132 [00:00<00:09, 12.78it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#   5%|▌         | 7/132 [00:00<00:12, 10.26it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#   8%|▊         | 11/132 [00:01<00:11, 10.18it/s]
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  10%|▉         | 13/132 [00:03<00:57,  2.08it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  11%|█         | 14/132 [00:03<00:51,  2.29it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  11%|█▏        | 15/132 [00:04<00:49,  2.38it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  13%|█▎        | 17/132 [00:04<00:38,  3.03it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  14%|█▎        | 18/132 [00:04<00:34,  3.28it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  14%|█▍        | 19/132 [00:05<00:48,  2.32it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  15%|█▌        | 20/132 [00:05<00:41,  2.68it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  96%|█████████▌| 127/132 [01:38<00:12,  2.48s/it]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  97%|█████████▋| 128/132 [01:40<00:10,  2.51s/it]
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  98%|█████████▊| 129/132 [01:43<00:07,  2.38s/it]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  98%|█████████▊| 130/132 [01:43<00:03,  1.85s/it]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
#  99%|█████████▉| 131/132 [01:44<00:01,  1.47s/it]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# 100%|██████████| 132/132 [01:45<00:00,  1.25it/s]
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False

# %%
metadata_final
# Out:
#                                 path  label   video_id
# 0         ./data/Video_0_frame_0.jpg      2    Video_0
# 1         ./data/Video_0_frame_1.jpg      2    Video_0
# 2         ./data/Video_0_frame_2.jpg      2    Video_0
# 3         ./data/Video_0_frame_3.jpg      2    Video_0
# 4         ./data/Video_0_frame_4.jpg      2    Video_0
# ...                              ...    ...        ...
# 19969  ./data/Video_131_frame_70.jpg      2  Video_131
# 19970  ./data/Video_131_frame_71.jpg      2  Video_131
# 19971  ./data/Video_131_frame_72.jpg      2  Video_131
# 19972  ./data/Video_131_frame_73.jpg      2  Video_131
# 19973  ./data/Video_131_frame_74.jpg      2  Video_131
#
# [19974 rows x 3 columns]

# %%
metadata_final.to_csv('covid_data.csv',index=False)
